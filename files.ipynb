# %%
f=open('data.csv','r')

# %%
f
# Out:
# <open file 'data.csv', mode 'r' at 0x7fc858313270>

# %%
data = f.read()

# %%
data
# Out:
# 'id,name,salary,address\n1,name1,1234,ad1\n2,name2,4567,ad2\n3,name3,8910,ad1\n'

# %%
print data
# Out:
# id,name,salary,address
# 1,name1,1234,ad1
# 2,name2,4567,ad2
# 3,name3,8910,ad1

# %%
f.close()

# %%
f=open('data.csv','r')
data = f.readlines()
print data
# Out:
# ['id,name,salary,address\n', '1,name1,1234,ad1\n', '2,name2,4567,ad2\n', '3,name3,8910,ad1\n']

# %%
f=open('data.csv','r')
data = f.read()
print "data=",data
data1 = f.read()
print "data1=",data1
# Out:
# data= id,name,salary,address
# 1,name1,1234,ad1
# 2,name2,4567,ad2
# 3,name3,8910,ad1
#
# data1=

# %%
f=open('data.csv','r')
data = f.read()
print "data=",data
f.close()
f=open('data.csv','r')
data1 = f.read()
print "data1=",data1
# Out:
# data= id,name,salary,address
# 1,name1,1234,ad1
# 2,name2,4567,ad2
# 3,name3,8910,ad1
#
# data1= id,name,salary,address
# 1,name1,1234,ad1
# 2,name2,4567,ad2
# 3,name3,8910,ad1

# %%
f=open('data.csv','r')
print "opened: ",f.tell()
data = f.read()
print "After read: ",f.tell()
print "data=",data
data1 = f.read()
print "After second read:",f.tell()
print "data1=",data1
print "Seeking the contrloer at first position"
f.seek(0)
print "Aftre seek: ",f.tell()
print "reading data from first"
data2 = f.read()
print "data2:",data2
print "seeking the controller at 9th position"
f.seek(9)
print f.tell()
print "reading data from 9th position"
data3 = f.read()
print "data2:",data3
# Out:
# opened:  0
# After read:  74
# data= id,name,salary,address
# 1,name1,1234,ad1
# 2,name2,4567,ad2
# 3,name3,8910,ad1
#
# After second read: 74
# data1=
# Seeking the contrloer at first position
# Aftre seek:  0
# reading data from first
# data2: id,name,salary,address
# 1,name1,1234,ad1
# 2,name2,4567,ad2
# 3,name3,8910,ad1
#
# seeking the controller at 9th position
# 9
# reading data from 9th position
# data2: alary,address
# 1,name1,1234,ad1
# 2,name2,4567,ad2
# 3,name3,8910,ad1

# %%
f=open('data.csv')
print f.readline()
# Out:
# id,name,salary,address

# %%
f.readline()
# Out:
# '1,name1,1234,ad1\n'

# %%
f.readline()
# Out:
# '2,name2,4567,ad2\n'

# %%
f=open('data.csv')
print "first line:",f.readline()
print "data:",f.read()
# Out:
# first line: id,name,salary,address
#
# data: 1,name1,1234,ad1
# 2,name2,4567,ad2
# 3,name3,8910,ad1

# %%
f=open('data1.csv','w')

# %%
f=open('data1.csv','w')
f.write("this is the first line of the file")

# %%
f=open('data1.csv','w')
f.write("this is the first line of the file")
f.close()

# %%
f=open('data1.csv','w')

# %%
f=open('data1.csv','w')
f.write("this is the first line of the file\n")
f.write("this is the second line of the file")

f.close()

# %%
f=open('data1.csv','w')
f.write("this is the first line of the file\n")
f.write("this is the second line of the file\n")
f.write("this is the second line of the file\n")
f.flush()
f.write("this is the fourth line of the file")

# %%
f=open('data1.csv','w')
f.write("this is the first line of the file\n")
f.write("this is the second line of the file\n")
f.close()

f.write("this is the third line of the file")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-d47143bca482> in <module>()
#       4 f.close()
#       5
# ----> 6 f.write("this is the third line of the file")
#
# ValueError: I/O operation on closed file

# %%
f=open('data1.csv','w')
f.write("this is the first line of the file\n")
f.write("this is the second line of the file\n")
f.write("this is the third line of the file\n")
f.flush()
f.write("this is the fourth line of the file")

# %%
f=open('data1.csv','w')
f.write("this is the first line of the file\n")
f.write("this is the second line of the file\n")
f.write("this is the third line of the file\n")
f.flush()
f.write("this is the fourth line of the file")
f.flush()

# %%
f=open('data1.csv','w')
l=['star1','str2','str3']
f.writelines(l)
f.close()

# %%
f=open('data1.csv','w')
l=['star1','str2','str3']
f.writelines(l)
f.close()

# %%
f=open('ms.jpg','rb')
data = f.read()

# %%
data
# Out:
# '\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00\xff\xdb\x00C\x00\x05\x03\x04\x04\x04\x03\x05\x04\x04\x04\x05\x05\x05\x06\x07\x0c\x08\x07\x07\x07\x07\x0f\x0b\x0b\t\x0c\x11\x0f\x12\x12\x11\x0f\x11\x11\x13\x16\x1c\x17\x13\x14\x1a\x15\x11\x11\x18!\x18\x1a\x1d\x1d\x1f\x1f\x1f\x13\x17"$"\x1e$\x1c\x1e\x1f\x1e\xff\xdb\x00CX\x03 \x03\x01"\x00\x02\x11\x01\x03\x11\x01\xff\xc4\x00\x1f\x00\x00\x01\x05\x01\x01\x01\x01\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x01\x02\x03\x04\x05\x06\x07\x08\t\n\x0b\xff\xc4\x00\xb5\x10\x00\x02\x01\x03\x03\x02\x04\x03\x05\x05\x04\x04\x00\x00\x01}\x01\x02\x03\x00\x04\x11\x05\x12!1A\x06\x13Qa\x07"q\x142\x81\x91\xa1\x08#B\xb1\xc1\x15R\xd1\xf0$3br\x82\t\n\x16\x17\x18\x19\x1a%&\'()*456789:CDEFGHIJSTUVWXYZcdefghijstuvwxyz\t\n\x0b\xff\xc4\x00\xb5\x11\x00\x02\x01\x02\x04\x04\x03\x04\x07\x05\x04\x04\x00\x01\x02w\x00\x01\x02\x03\x11\x04\x05!1\x06\x12AQ\x07aq\x13"2\x81\x08\x14B\x91\xa1\xb1\xc1\t#3R\xf0\x15br\xd1\n\x16$4\xe1%\xf1\x17\x18\x19\x1a&\'()*56789:CDEFGHIJSTUVWXYZcdefghijstuvwxyz?\x00\xfb.\x8a(\xa0\x02\x8a(\xa0\x02\x8a(\xa0\x02\x8a(\xa0\x02\x8a(\xa0\x02\x8a(\xa0\x02\x8a(\xa0\x02\x8a(\xa0\x02\x8a(\xa0\x02\x8a(\xa0\x02\x8a(\xa0\x02\x8a(\xa0\x02\x8a(\xa0\x02\x8a(\xa0\x02\x8a(\xa0\x02\x8a(\xa0\x02\x8a(\xa0\x02\x8a(\xa0\x02\x8a(\xa0\x02\x8a(\xa0\x02\x8a(\xa0\x02\x8a(\xa0\x02\x8a(\xa0\x02\x8a(\xa0\x02\x8a(\xa0\x02\x8a(\xa0\x02\x8a(\xa0\x02\x8a(\xa0\x02\x8a(\xa0\x02\x8a(\xa0\x02\x8a(\xa0\x02\x8a(\xa0\x02\x8a(\xa0\x02\x8a(\xa0\x02\x8a(\xa0\x02\x8a(\xa0\x02\x8a(\xa0\x02\x8a(\xa0\x02\x8a(\xa0\x02\x8a(\xa0\x02\x8a(\xa0\x02\x8a(\xa0\x02\x8a(\xa0\x02\x8a(\xa0\x02\x8a(\xa0\x02\x8a(\xa0\x02\x8a(\xa0\x02\x8a(\xa0\x02\x8a(\xa0\x02\x8a(\xa0\x02\x8a(\xa0\x02\x8a(\xa0\x02\x8a(\xa0\x02\x8a(\xa0\x02\x8a(\xa0\x02\x8a(\xa0\x02\x8a(\xa0\x02\x8a(\xa0\x02\x8a(\xa0\x02\x8a(\xa0\x02\x8a(\xa0\x02\x8a(\xa0\x02\x8a(\xa0\x02\x8a(\xa0\x02\x8a(\xa0\x02\x8a(\xa0\x02\x8a\xc4\xd6\xfca\xe1-\n\xe9\xedu\xbf\x14\xe8ze\xc4qy\xcf\x15\xe6\xa1\x14.\xb1\xe4\r\xe43\x02\x17$\x0c\xf4\xe4R\xe9\xfe-\xf0\xa6\xa1\xaaE\xa5Xx\x9bE\xbb\xd4%\x84O\x1d\xac\x17\xf1<\xaf\x19\x19\x0e\x106J\xe0\xe78\xc5\x0b]\x81\xe8mQX\xb2x\xbb\xc2\x91\xd8\\_\xc9\xe2}\x11,\xedn>\xcbq;_\xc4#\x86n?v\xcd\xbb\n\xfc\x8f\x94\xf3\xc8\xac\xdb\x7f\x88\xbe\x0e\x9f\xc7w\xfe\n\x1a\xe5\x92k\x160\xc5$\x91=\xc4k\xb8\xbe\xf3\xb1Al\xb3\xa8M\xcc\x00\xe02\xfa\xf0\x06\xc7YErz\xaf\x8c\xf4\xab\xcf\x0ck\xb7\xbe\x10\xf1\x06\x83\xaa\xea\x1ae\x9b\xceR;\x95\xb9H\xca\xa9`$X\xdf \x1d\xa7\xb8\xaa_\n~!i>7\xf0\x86\x93<:\xee\x81/\x88\xeet\xa8n\xef,-.\x95\xda\xdeG\x8dI\xccA\xcb\xaa\x868\xe7\x9fz\x16\xb7\xb7K~7\xff\x00&6\xadf\xfa\xfe\x96\xff\x003\xb9\xa2\xb8/\x85\xbe8\x9bZ\xf8}q\xe2O\x16\xdc\xe9:i\xb4\xd4om\'\x9d\t\x82\xddV\x0b\x87\x89X\x99\x1c\xed\xc8Q\x9c\xb7S]\x8e\x8d\xaa\xe9z\xd6\x9e\x9a\x86\x8f\xa9Y\xeaVr\x12\x12\xe2\xd2u\x966\xc1\xc1\xc3) \xe0\xd0\xb5W_\xd5\xc5\xff\x00\x05}\xc5\xca(\xa2\x80\n(\xa2\x80\n(\xa2\x80\n(\xa2\x80\n(\xa2\x80\n(\xa2\x80\n(\xa2\x80\n(\xa2\x80\n(\xa2\x80\n(\xa2\x80\ ...

# %%
f=open('ms1.jpg','wb')
f.write(data)
f.close()

# %%
f=open('f1.txt','w')
f.write(1234)
f.close()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-32-986dcae86eb2> in <module>()
#       1 f=open('f1.txt','w')
# ----> 2 f.write(1234)
#       3 f.close()
#
# TypeError: expected a string or other character buffer object

# %%
f=open('f1.txt','w')
f.write(str(1234))
f.close()

# %%
# list, dictionaries and integers, float complex
